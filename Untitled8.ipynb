# %% [markdown]
# <a href="https://colab.research.google.com/github/mikicapro/python/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Milance', 'Mare', 'Mixa', 'Matuf','Tatko','Mamca'
sizes = [6, 9, 11, 13,41, 46]
explode = (0.01, 0.01, 0.011, 0.1,0.01,0.02)  # only "explode" the 2nd slice (i.e. 'Mamica')
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
    	shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
