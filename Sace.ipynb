# %% [markdown]
# <a href="https://colab.research.google.com/github/mikicapro/python/blob/master/Sace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [0,0, 1, 2,2,1]
y = [0,1, 2, 2,1,0]
fig, ax = plt.subplots()
ax.fill(x, y)
plt.show()
